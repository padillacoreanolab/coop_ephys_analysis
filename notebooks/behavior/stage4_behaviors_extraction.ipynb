# %%
# Autoreload all modules so that changes in the code are reflected without needing to restart the kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# [autoreload of coop_ephys_analysis.behavior failed: Traceback (most recent call last):
#   File "c:\Users\zhaoz\miniforge3\envs\coop_ephys_env\lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\zhaoz\miniforge3\envs\coop_ephys_env\lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "c:\Users\zhaoz\miniforge3\envs\coop_ephys_env\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\zhaoz\Desktop\Research\Cooperation\coop_ephys_analysis\src\coop_ephys_analysis\behavior\__init__.py", line 13, in <module>
#     from .behavior_qc import (
# ...

# %% [markdown]
# # Stage 4 Behavior Extraction
#
# This notebook runs the behavior extraction pipeline using the reusable `ecu_extraction` module.

# %%
from pathlib import Path
import sys

#CHANGE THIS PATH TO YOUR LOCAL REPO ROOT
repo_root = Path(r"C:\Users\zhaoz\Desktop\Research\Cooperation\coop_ephys_analysis")
sys.path.append(str(repo_root))
sys.path.append(str(repo_root / "src"))

from coop_ephys_analysis.behavior import ecu_extraction as extract
from coop_ephys_analysis.behavior import behavior_qc as qc

# %% [markdown]
# ## Paths

# %%
#CHANGE THE PATHS BELOW TO YOUR LOCAL PATHS TO THE BEHAVIOR FILES AND OUTPUT DIRECTORY
behavior_root = Path(r"C:\Users\zhaoz\Desktop\Research\Cooperation\coop_ephys_analysis\data\raw\Stage4")
output_dir = Path(r"C:\Users\zhaoz\Desktop\Research\Cooperation\coop_ephys_analysis\data\processed\stage4_behaviors")
box_map_csv = behavior_root / "Coop_ephys_Box_organization(Sheet1).csv"

behavior_root, box_map_csv
# Out:
# (WindowsPath('C:/Users/zhaoz/Desktop/Research/Cooperation/coop_ephys_analysis/data/raw/Stage4'),
#  WindowsPath('C:/Users/zhaoz/Desktop/Research/Cooperation/coop_ephys_analysis/data/raw/Stage4/Coop_ephys_Box_organization(Sheet1).csv'))

# %% [markdown]
# ## Load Recording-To-Box Map

# %%
recording_to_box = extract.load_recording_box_map(box_map_csv)
len(recording_to_box)
# Out:
# 89

# %% [markdown]
# ## Extract Behaviors From Stage Folders

# %%
'''
Expected folder architecture:
	root_path/
		Coop_ephys_Box_organization(Sheet1).csv
		Stage4_D1/
			20250508_100203_Stage4_D1_1-2_merged.DIO/
				20250508_100203_Stage4_D1_1-2_merged.dio_ECU_Din1.dat
				20250508_100203_Stage4_D1_1-2_merged.dio_ECU_Din10.dat
				...
			20250508_100203_Stage4_D1_1-3_merged.DIO/
				...
		Stage4_D2/
			...
'''

stage_behaviors = extract.extract_from_folder(
    root_path=behavior_root,
    recording_to_box=recording_to_box,
    output_dir=output_dir,
    save=True,
)

stage_behaviors.keys()
# Out:
# C:\Users\zhaoz\Desktop\Research\Cooperation\coop_ephys_analysis\external\diff_fam_social_memory_ephys\trodes\read_exported.py:219: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(dtype_spec)
# In Stage4_D1, 10 mice have been processed.
# In Stage4_D2, 7 mice have been processed.
# In Stage4_D3, 10 mice have been processed.
# In Stage4_D4, 10 mice have been processed.
# In Stage4_D5, 10 mice have been processed.
# In Stage4_D6, 9 mice have been processed.
# In Stage4_D7, 10 mice have been processed.
# In Stage4_D8, 10 mice have been processed.
# dict_keys(['Stage4_D1', 'Stage4_D2', 'Stage4_D3', 'Stage4_D4', 'Stage4_D5', 'Stage4_D6', 'Stage4_D7', 'Stage4_D8'])

# %% [markdown]
# ## Validate Saved Pickle

# %%
stage4_d1_behaviors = extract.load_pickle(output_dir / "Stage4_D1.pkl")
list(stage4_d1_behaviors.keys())[:5]
stage4_d1_behaviors['20250508_100203_Stage4_D1_1-2_merged']
# Out:
# {'selfish light': array([[  47.44435,   52.4442 ],
#         [  54.48395,   59.48405],
#         [  69.57465,   74.57435],
#         [  76.06425,   81.0643 ],
#         [  83.27445,   88.2744 ],
#         [  92.2647 ,   97.2645 ],
#         [ 100.65455,  105.6546 ],
#         [ 110.05475,  115.05495],
#         [ 117.51475,  122.5149 ],
#         [ 126.27485,  131.2749 ],
#         [ 135.25535,  140.25505],
#         [ 147.7151 ,  152.7152 ],
#         [ 160.91525,  165.9155 ],
#         [ 169.0854 ,  174.0857 ],
#         [ 177.2555 ,  182.2557 ],
#         [ 187.546  ,  192.54555],
#         [ 196.2057 ,  201.2062 ],
#         [ 204.58595,  209.5859 ],
#         [ 212.02595,  217.026  ],
#         [ 222.44605,  227.44635],
#         [ 234.1962 ,  239.19625],
#         [ 243.08655,  248.08635],
#         [ 250.3164 ,  255.31635],
#         [ 257.8965 ,  262.89655],
#         [ 266.6166 ,  271.6169 ],
#         [ 273.98685,  278.98675],
#         [ 282.0568 ,  287.05685],
# ...

# %% [markdown]
# ## Count Events

# %%
qc.count_events(stage4_d1_behaviors['20250508_100203_Stage4_D1_1-2_merged'], 
				mode='single recording', 
				recording_name='20250508_100203_Stage4_D1_1-2_merged')
# Out:
# 20250508_100203_Stage4_D1_1-2_merged
# # selfish light - 178
# # coop nose poke - 136
# # recipient port entry - 139
# # coop light - 125
# # selfish nose poke - 60
# # subject port entry - 323

# %%
qc.count_events(stage4_d1_behaviors, mode='multiple recordings', stage=4, day=1)
# Out:
# Stage 4 Day 1
# --------------------
# 20250508_100203_Stage4_D1_1-2_merged
# # selfish light - 178
# # coop nose poke - 136
# # recipient port entry - 139
# # coop light - 125
# # selfish nose poke - 60
# # subject port entry - 323
#
# 20250508_100203_Stage4_D1_1-3_merged
# # selfish light - 178
# # coop nose poke - 136
# # recipient port entry - 139
# # coop light - 125
# # selfish nose poke - 60
# # subject port entry - 323
#
# 20250508_100203_Stage4_D1_2-1_merged
# # selfish nose poke - 86
# # subject port entry - 272
# # coop nose poke - 89
# # selfish light - 151
# # recipient port entry - 354
# # coop light - 82
#
# 20250508_100203_Stage4_D1_2-4_merged
# # selfish nose poke - 86
# # subject port entry - 272
# # coop nose poke - 89
# # selfish light - 151
# # recipient port entry - 354
# # coop light - 82
#
# 20250508_112121_Stage4_D1_6-1_merged
# # selfish light - 190
# # coop nose poke - 164
# # recipient port entry - 1
# # coop light - 147
# # selfish nose poke - 60
# ...

# %% [markdown]
# ## Extract One Recording

# %%
example_dio_path = behavior_root / "Stage4_D1" / "20250508_100203_Stage4_D1_1-2_merged.DIO"

rec_name, rec_behaviors = extract.load_trodes_recording(
    dio_path=example_dio_path,
    recording_to_box=recording_to_box,
)

rec_name, {behavior_name: len(events) for behavior_name, events in rec_behaviors.items()}
# Out:
# ('20250508_100203_Stage4_D1_1-2_merged',
#  {'selfish light': 178,
#   'coop nose poke': 136,
#   'recipient port entry': 139,
#   'coop light': 125,
#   'selfish nose poke': 60,
#   'subject port entry': 323})
